# %%
# !nvidia-smi
# Out:
# Wed Sep 15 18:40:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0 Off |                  N/A |
# | N/A   70C    P0    35W /  N/A |    483MiB /  5934MiB |     17%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.10.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2021.8.28)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.8/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.62.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: huggingface-hub>=0.0.12 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.0.16)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from transformers) (21.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.0.12->transformers) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->transformers) (2.4.7)

# %%
import torch
import random
import numpy as np
import time
import datetime
import seaborn as sns
import pandas as pd
import os
import pathlib
import json
import re
from random import randrange

import matplotlib.pyplot as plt
# %matplotlib inline

from transformers import GPT2LMHeadModel, GPT2Tokenizer, GPT2Config, GPT2LMHeadModel, GPTNeoForCausalLM
from transformers import AdamW, get_linear_schedule_with_warmup
from transformers import Trainer, TrainingArguments

# %%
seed = random.randint(0, 2 ** 32 - 1)
# Tell pytorch to run this model on the GPU.
device_name = "cuda:0" if torch.cuda.is_available() else "cpu"
device = torch.device(device_name)
print(f"Will use {device_name} for training with seed: {seed}")
# Out:
# Will use cuda:0 for training with seed: 2641404581

# %%
if os.path.isdir("/opt/awsw"):
  # In case we run this locally (in Docker)
  work_dir = os.path.join("/opt", "awsw")
else:
  from google.colab import drive
  drive.mount('/content/drive')
  work_dir = os.path.join("/content", "drive", "MyDrive", "endless_awsw")

models_dir = os.path.join(work_dir, "models")

if not os.path.isdir(models_dir):
    pathlib.Path(models_dir).mkdir(parents=True, exist_ok=True)
    
tokenizer = GPT2Tokenizer.from_pretrained('EleutherAI/gpt-neo-125M', bos_token='<|startoftext|>', eos_token='<|endoftext|>', pad_token='<|pad|>') #gpt2-medium
# model = GPT2LMHeadModel.from_pretrained('EleutherAI/gpt-neo-125M', pad_token_id = tokenizer.pad_token_id)
model = GPTNeoForCausalLM.from_pretrained('EleutherAI/gpt-neo-125M', pad_token_id = tokenizer.pad_token_id, eos_token_id=tokenizer.eos_token_id)
model.config.attention_dropout = 0.2
model.config.embed_dropout = 0.2
print(f"Loading empty, pre-trained model.")

model.to(device)
model.resize_token_embeddings(len(tokenizer))
print(f"Model attached to {device_name}")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading empty, pre-trained model.
# Model attached to cuda:0

# %% [markdown]
# # Split data

# %%
with open("awsw_story_input.txt") as f:
    data = f.read()
lines = data.split("\n")
player_dragon_pairs = {}
last_player_talk = []
closed_player_talk = False
re_player_talk = re.compile(r'c "(.*?)"')
for line in lines:
    line = line.strip()
    line_split = line.split(" ")
    if len(line_split) <= 1:
        continue
    
    if line_split[0] == "c":
        if closed_player_talk:
            closed_player_talk = False
            last_player_talk = []
        last_player_talk.append(re.sub(re_player_talk, r"\1", line))
    else:
        if not closed_player_talk:
            last_player_talk = json.dumps(last_player_talk)
            if not last_player_talk in player_dragon_pairs:
                player_dragon_pairs[last_player_talk] = []
            closed_player_talk = True
            
        line = "DragonReply " + line
        if last_player_talk is not None:
            player_dragon_pairs[last_player_talk].append(line)
    
train_lines = []
eval_lines = []
eval_per_character = 0

for player_line_str in player_dragon_pairs.keys():
    player_lines = json.loads(player_line_str)
    dragon_lines = player_dragon_pairs[player_line_str]
    compiled_line = " ".join([f'PlayerReply c "{player_line}"' for player_line in player_lines]) + " " + " ".join(dragon_lines)
    train_lines.append(compiled_line)
    
test_bucket = {}
for l in train_lines:
    l_split = l.split(" ")
    character = None
    for i, ls in enumerate(l_split):
        if ls == "DragonReply":
            character = l_split[i + 1]
            break
    if not character in test_bucket:
        test_bucket[character] = []
    test_bucket[character].append(l)
    
for i in range(eval_per_character):
    for character in test_bucket.keys():
        random_line = test_bucket[character][randrange(len(test_bucket[character]))]
        eval_lines.append(random_line)
        for i2, t in enumerate(train_lines):
            if t == random_line:
                del train_lines[i2]
                break
    
joined_eval_lines = "\n".join(eval_lines[:5])
print(f"eval_lines: {joined_eval_lines}")
joined_train_lines = "\n".join(train_lines[:5])
print(f"train_lines: {joined_train_lines}")

if not os.path.isfile("data_train.txt"):
    with open("data_train.txt", "w") as f:
        for l in train_lines:
            f.write(l + "\n")
            
if not os.path.isfile("data_test.txt"):
    with open("data_test.txt", "w") as f:
        for l in eval_lines:
            f.write(l + "\n")
# Out:
# eval_lines:
# train_lines: PlayerReply c "Hey, Remy!" DragonReply Ry "Hello, [player_name]."
# PlayerReply c "Is there any particular reason why you wanted to meet here?" DragonReply Ry "I enjoy Tatsu Park is all. Have you been here before?"
# PlayerReply c "Can't say I have." PlayerReply c "A few times." PlayerReply c "Once or twice." DragonReply Ry "I see." DragonReply Ry "Well, what do you think of it?"
# PlayerReply c "It's pretty idyllic." DragonReply Ry smile "It is. I like it a lot here."
# PlayerReply c "It's pretty romantic." DragonReply Ry shy "You think so?"

# %%
from datasets import load_dataset
dataset = load_dataset('text', data_files={'train': os.path.join(work_dir, "data_train.txt"), 'test': os.path.join(work_dir, "data_test.txt")})
def encode(batch):
    encoded = tokenizer([f"{text}<|endoftext|>" for text in batch['text']])
    return encoded

def group_texts(examples):
    # Make a max size
    block_size = 128
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the small remainder, we could add padding if the model supported it instead of this drop, you can
    # customize this part to your needs.
    total_length = (total_length // block_size) * block_size
    # Split by chunks of block_size.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

def map_dragon_reply_text(batch):
    # Make a max size
    block_size = 128
    result = {'text': []}
    for item in batch['text']:
        # PlayerReply c "A lot." PlayerReply c "A little." PlayerReply c "None at all." DragonReply An "I see."
        item_split = item.split(" ")
        player_replies = []
        dragon_replies = []
        current_reply = []
        handling_reply = None
        for token in item_split:
            if token == "PlayerReply":
                if handling_reply is None:
                    handling_reply = "PlayerReply"
                else:
                    if handling_reply == "PlayerReply":
                        # We need to store the PlayerReply
                        player_replies.append(" ".join(current_reply))
                        current_reply = []
            elif token == "DragonReply":
                if handling_reply == "DragonReply":
                    # We need to store the DragonReply
                    dragon_replies.append(" ".join(current_reply))
                    current_reply = []
                    
                if handling_reply == "PlayerReply":
                    # We need to store the PlayerReply
                    player_replies.append(" ".join(current_reply))
                    current_reply = []
                    
                handling_reply = "DragonReply"
                current_reply = []
                    
            if handling_reply is not None:
                current_reply.append(token)
                
        # There's always a dragon reply at the end.
        dragon_replies.append(" ".join(current_reply))
        for player_idx in range(len(player_replies)):
            for dragon_idx in range(len(dragon_replies)):
                result['text'].append(player_replies[player_idx] + " " + dragon_replies[dragon_idx])
                
    return result

dataset = dataset.map(
    map_dragon_reply_text,
    batched=True,
    batch_size=1000,
    num_proc=4
)

dataset = dataset.map(
    encode,
    batched=True,
    batch_size=1000,
    remove_columns=["text"],
    num_proc=4
)

dataset = dataset.map(
    group_texts,
    batched=True,
    batch_size=1000,
    num_proc=4
)

tokenizer.decode(dataset['train'][0]['input_ids'])
# Out:
# Using custom data configuration default-76ad15c03141303b
# Reusing dataset text (/home/awsw-dev/.cache/huggingface/datasets/text/default-76ad15c03141303b/0.0.0/e16f44aa1b321ece1f87b07977cc5d70be93d69b20486d6dacd62e12cf25c9a5)
# 'PlayerReply c "Hey, Remy!" DragonReply Ry "Hello, [player_name]."<|endoftext|>PlayerReply c "Is there any particular reason why you wanted to meet here?" DragonReply Ry "I enjoy Tatsu Park is all. Have you been here before?"<|endoftext|>PlayerReply c "Can\'t say I have." DragonReply Ry "I see."<|endoftext|>PlayerReply c "Can\'t say I have." DragonReply Ry "Well, what do you think of it?"<|endoftext|>PlayerReply c "A few times." DragonReply Ry "I see."<|endoftext|>PlayerReply c "A few times." DragonReply Ry "Well, what'

# %%
class AWSWTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        if self.label_smoother is not None and "labels" in inputs:
            labels = inputs.pop("labels")
        else:
            labels = None
        outputs = model(**inputs)
        
        # Save past state if it exists
        # TODO: this needs to be fixed and made cleaner later.
        if self.args.past_index >= 0:
            self._past = outputs[self.args.past_index]

        if labels is not None:
            loss = self.label_smoother(outputs, labels)
        else:
            # We don't use .loss here since the model may return tuples instead of ModelOutput.
            loss = outputs["loss"] if isinstance(outputs, dict) else outputs[0]

        return (loss, outputs) if return_outputs else loss

def train(model):
    training_args = TrainingArguments(
        models_dir,
        seed=seed,
        per_device_train_batch_size=5,
        per_device_eval_batch_size=5,
        num_train_epochs=100,
        save_total_limit=2,
        save_steps=1000
    )
    trainer = Trainer(
        model=model, 
        args=training_args, 
        train_dataset=dataset['train'], 
        #eval_dataset=dataset['test']
    )
    checkpoint_dirs = [os.path.join(models_dir, d) for d in os.listdir(models_dir) if os.path.isdir(os.path.join(models_dir, d))]
    if len(checkpoint_dirs) > 0:
        latest_checkpoint = max(checkpoint_dirs, key=os.path.getmtime)
        trainer.train(latest_checkpoint)
    else:
        trainer.train()

train(model)
# Out:
# ***** Running training *****
#   Num examples = 4570
#   Num Epochs = 100
#   Instantaneous batch size per device = 5
#   Total train batch size (w. parallel, distributed & accumulation) = 5
#   Gradient Accumulation steps = 1
#   Total optimization steps = 91400
#     <div>
#
#       <progress value='91400' max='91400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [91400/91400 5:57:08, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.850100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.405900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.153700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.051400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.925900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.815400</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.740800</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.612300</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.590600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.467700</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.456800</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.339800</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.336500</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.265300</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.242400</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.201300</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.174000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.154700</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.125700</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.121700</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.094900</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.097100</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.078200</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.077800</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.068800</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.067500</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.062700</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.059800</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.058400</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.054100</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.054900</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.049000</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.052000</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.047800</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.047900</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.046000</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.045100</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.044900</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.042000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.043900</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.041400</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.042500</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.038600</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.041400</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.038800</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.038400</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.038000</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.038400</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.036700</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.037000</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.037500</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.034600</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.037200</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.033600</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.036300</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.033400</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>0.034800</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.033900</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>0.034100</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.034400</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.033200</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.033700</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.031400</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.034300</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>0.030800</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.033100</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>0.030900</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.033400</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>0.031700</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>0.030700</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>0.032300</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>0.030500</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>0.031800</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>0.029800</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>0.031800</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>0.030100</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>0.030600</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>0.030100</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>0.030100</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>0.029700</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>0.029500</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>0.030600</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>0.029000</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>0.030500</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>0.028400</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>0.030000</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>0.028000</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>0.029300</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>0.028800</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>0.028600</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>0.028500</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>0.028900</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>0.028500</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>0.027300</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>0.029300</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>0.027000</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>0.028900</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>0.027200</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>0.028600</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>0.027700</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>0.027700</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>0.027900</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>0.027000</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>0.027900</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>0.026500</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>0.028300</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>0.026700</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>0.027200</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>0.026200</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>0.027000</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>0.026600</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>0.027300</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>0.027200</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>0.026100</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>0.027400</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>0.025400</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>0.027600</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>0.025500</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>0.026800</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>0.025900</td>
# Saving model checkpoint to /opt/awsw/models/checkpoint-1000
# Configuration saved in /opt/awsw/models/checkpoint-1000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to /opt/awsw/models/checkpoint-2000
# Configuration saved in /opt/awsw/models/checkpoint-2000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-2000/pytorch_model.bin
# Saving model checkpoint to /opt/awsw/models/checkpoint-3000
# Configuration saved in /opt/awsw/models/checkpoint-3000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-4000
# Configuration saved in /opt/awsw/models/checkpoint-4000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-4000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-5000
# Configuration saved in /opt/awsw/models/checkpoint-5000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-5000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-6000
# Configuration saved in /opt/awsw/models/checkpoint-6000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-6000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-7000
# Configuration saved in /opt/awsw/models/checkpoint-7000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-7000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-8000
# Configuration saved in /opt/awsw/models/checkpoint-8000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-8000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-9000
# Configuration saved in /opt/awsw/models/checkpoint-9000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-9000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-10000
# Configuration saved in /opt/awsw/models/checkpoint-10000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-10000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-11000
# Configuration saved in /opt/awsw/models/checkpoint-11000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-11000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-12000
# Configuration saved in /opt/awsw/models/checkpoint-12000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-12000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-13000
# Configuration saved in /opt/awsw/models/checkpoint-13000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-13000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-14000
# Configuration saved in /opt/awsw/models/checkpoint-14000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-14000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-12000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-15000
# Configuration saved in /opt/awsw/models/checkpoint-15000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-15000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-16000
# Configuration saved in /opt/awsw/models/checkpoint-16000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-16000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-14000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-17000
# Configuration saved in /opt/awsw/models/checkpoint-17000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-17000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-18000
# Configuration saved in /opt/awsw/models/checkpoint-18000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-18000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-19000
# Configuration saved in /opt/awsw/models/checkpoint-19000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-19000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-20000
# Configuration saved in /opt/awsw/models/checkpoint-20000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-20000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-21000
# Configuration saved in /opt/awsw/models/checkpoint-21000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-21000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-19000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-22000
# Configuration saved in /opt/awsw/models/checkpoint-22000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-22000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-20000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-23000
# Configuration saved in /opt/awsw/models/checkpoint-23000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-23000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-21000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-24000
# Configuration saved in /opt/awsw/models/checkpoint-24000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-24000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-22000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-25000
# Configuration saved in /opt/awsw/models/checkpoint-25000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-25000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-23000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-26000
# Configuration saved in /opt/awsw/models/checkpoint-26000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-26000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-24000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-27000
# Configuration saved in /opt/awsw/models/checkpoint-27000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-27000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-25000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-28000
# Configuration saved in /opt/awsw/models/checkpoint-28000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-28000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-26000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-29000
# Configuration saved in /opt/awsw/models/checkpoint-29000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-29000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-27000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-30000
# Configuration saved in /opt/awsw/models/checkpoint-30000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-30000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-28000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-31000
# Configuration saved in /opt/awsw/models/checkpoint-31000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-31000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-29000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-32000
# Configuration saved in /opt/awsw/models/checkpoint-32000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-32000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-30000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-33000
# Configuration saved in /opt/awsw/models/checkpoint-33000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-33000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-31000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-34000
# Configuration saved in /opt/awsw/models/checkpoint-34000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-34000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-32000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-35000
# Configuration saved in /opt/awsw/models/checkpoint-35000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-35000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-33000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-36000
# Configuration saved in /opt/awsw/models/checkpoint-36000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-36000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-34000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-37000
# Configuration saved in /opt/awsw/models/checkpoint-37000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-37000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-35000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-38000
# Configuration saved in /opt/awsw/models/checkpoint-38000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-38000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-36000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-39000
# Configuration saved in /opt/awsw/models/checkpoint-39000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-39000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-37000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-40000
# Configuration saved in /opt/awsw/models/checkpoint-40000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-40000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-38000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-41000
# Configuration saved in /opt/awsw/models/checkpoint-41000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-41000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-39000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-42000
# Configuration saved in /opt/awsw/models/checkpoint-42000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-42000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-40000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-43000
# Configuration saved in /opt/awsw/models/checkpoint-43000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-43000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-41000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-44000
# Configuration saved in /opt/awsw/models/checkpoint-44000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-44000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-42000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-45000
# Configuration saved in /opt/awsw/models/checkpoint-45000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-45000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-43000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-46000
# Configuration saved in /opt/awsw/models/checkpoint-46000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-46000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-44000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-47000
# Configuration saved in /opt/awsw/models/checkpoint-47000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-47000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-45000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-48000
# Configuration saved in /opt/awsw/models/checkpoint-48000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-48000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-46000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-49000
# Configuration saved in /opt/awsw/models/checkpoint-49000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-49000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-47000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-50000
# Configuration saved in /opt/awsw/models/checkpoint-50000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-50000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-48000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-51000
# Configuration saved in /opt/awsw/models/checkpoint-51000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-51000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-49000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-52000
# Configuration saved in /opt/awsw/models/checkpoint-52000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-52000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-50000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-53000
# Configuration saved in /opt/awsw/models/checkpoint-53000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-53000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-51000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-54000
# Configuration saved in /opt/awsw/models/checkpoint-54000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-54000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-52000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-55000
# Configuration saved in /opt/awsw/models/checkpoint-55000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-55000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-53000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-56000
# Configuration saved in /opt/awsw/models/checkpoint-56000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-56000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-54000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-57000
# Configuration saved in /opt/awsw/models/checkpoint-57000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-57000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-55000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-58000
# Configuration saved in /opt/awsw/models/checkpoint-58000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-58000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-56000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-59000
# Configuration saved in /opt/awsw/models/checkpoint-59000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-59000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-57000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-60000
# Configuration saved in /opt/awsw/models/checkpoint-60000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-60000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-58000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-61000
# Configuration saved in /opt/awsw/models/checkpoint-61000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-61000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-59000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-62000
# Configuration saved in /opt/awsw/models/checkpoint-62000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-62000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-60000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-63000
# Configuration saved in /opt/awsw/models/checkpoint-63000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-63000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-61000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-64000
# Configuration saved in /opt/awsw/models/checkpoint-64000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-64000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-62000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-65000
# Configuration saved in /opt/awsw/models/checkpoint-65000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-65000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-63000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-66000
# Configuration saved in /opt/awsw/models/checkpoint-66000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-66000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-64000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-67000
# Configuration saved in /opt/awsw/models/checkpoint-67000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-67000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-65000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-68000
# Configuration saved in /opt/awsw/models/checkpoint-68000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-68000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-66000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-69000
# Configuration saved in /opt/awsw/models/checkpoint-69000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-69000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-67000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-70000
# Configuration saved in /opt/awsw/models/checkpoint-70000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-70000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-68000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-71000
# Configuration saved in /opt/awsw/models/checkpoint-71000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-71000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-69000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-72000
# Configuration saved in /opt/awsw/models/checkpoint-72000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-72000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-70000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-73000
# Configuration saved in /opt/awsw/models/checkpoint-73000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-73000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-71000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-74000
# Configuration saved in /opt/awsw/models/checkpoint-74000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-74000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-72000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-75000
# Configuration saved in /opt/awsw/models/checkpoint-75000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-75000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-73000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-76000
# Configuration saved in /opt/awsw/models/checkpoint-76000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-76000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-74000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-77000
# Configuration saved in /opt/awsw/models/checkpoint-77000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-77000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-75000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-78000
# Configuration saved in /opt/awsw/models/checkpoint-78000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-78000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-76000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-79000
# Configuration saved in /opt/awsw/models/checkpoint-79000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-79000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-77000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-80000
# Configuration saved in /opt/awsw/models/checkpoint-80000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-80000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-78000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-81000
# Configuration saved in /opt/awsw/models/checkpoint-81000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-81000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-79000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-82000
# Configuration saved in /opt/awsw/models/checkpoint-82000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-82000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-80000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-83000
# Configuration saved in /opt/awsw/models/checkpoint-83000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-83000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-81000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-84000
# Configuration saved in /opt/awsw/models/checkpoint-84000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-84000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-82000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-85000
# Configuration saved in /opt/awsw/models/checkpoint-85000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-85000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-83000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-86000
# Configuration saved in /opt/awsw/models/checkpoint-86000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-86000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-84000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-87000
# Configuration saved in /opt/awsw/models/checkpoint-87000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-87000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-85000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-88000
# Configuration saved in /opt/awsw/models/checkpoint-88000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-88000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-86000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-89000
# Configuration saved in /opt/awsw/models/checkpoint-89000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-89000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-87000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-90000
# Configuration saved in /opt/awsw/models/checkpoint-90000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-90000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-88000] due to args.save_total_limit
# Saving model checkpoint to /opt/awsw/models/checkpoint-91000
# Configuration saved in /opt/awsw/models/checkpoint-91000/config.json
# Model weights saved in /opt/awsw/models/checkpoint-91000/pytorch_model.bin
# Deleting older checkpoint [/opt/awsw/models/checkpoint-89000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)

# %% [markdown]
# # Testing
#
# We created a few past (for context) + present prompts (player input) and see the different reactions. This way, we can test the models across different iterations.

# %%
def generate_dragon_reply(past, prompt, top_k=50, top_p=0.95):
    block_size = 128
    model.eval()
    prompt = f'{past} PlayerReply c "{prompt}" DragonReply'
    generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
    generated = generated.to(device)

    sample_outputs = model.generate(
        generated, 
        pad_token_id=tokenizer.eos_token_id,
        max_length = block_size,
        num_return_sequences=1
    )
    return tokenizer.decode(sample_outputs[0], skip_special_tokens=False)[len(prompt):].strip()

prompts = [
    ('PlayerReply c "Hey Remy!" DragonReply Ry "Hey!"', "How are you?"),
    ('PlayerReply c "I was with Lorem today." DragonReply Ad "That\'s awesome. He\'s a cute fellow."', "What do you think of Lorem?"),
    ('DragonReply m "In Tatsu park, Adine and I sat down."', "Oh my god, Adine. What is this?"),
    ('DragonReply m "I sat down on a chair in Anna\'s lab."', "What will we do here?"),
]

# Set a fixed seed to make sure we get the same response every time.
torch.manual_seed(80085)
for (past, prompt) in prompts:
    reply = generate_dragon_reply(past, prompt)
    print(f"Prompt: {prompt}\nReply: {reply}\n\n")
# Out:
# Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
#
# Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
#
# Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
#
# Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>

# %% [markdown]
# # Sampling test
#
# Which combination is the best?

# %%
random.seed(80085)
for i in range(100):
    torch.manual_seed(80085)
    top_k = random.randint(0, 100)
    top_p = round(random.uniform(0, 1), 2)
    for (past, prompt) in prompts:
        reply = generate_dragon_reply(past, prompt, top_k = top_k, top_p = top_p)
        print(f"[Test {i + 1} top_k: {top_k}, top_p: {top_p}] -> Prompt: {prompt}\nReply: {reply}\n")
    print("-------------")
# Out:
# [Test 1 top_k: 64, top_p: 0.67] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 1 top_k: 64, top_p: 0.67] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 1 top_k: 64, top_p: 0.67] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 1 top_k: 64, top_p: 0.67] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 2 top_k: 61, top_p: 0.28] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 2 top_k: 61, top_p: 0.28] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 2 top_k: 61, top_p: 0.28] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 2 top_k: 61, top_p: 0.28] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 3 top_k: 47, top_p: 0.25] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 3 top_k: 47, top_p: 0.25] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 3 top_k: 47, top_p: 0.25] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 3 top_k: 47, top_p: 0.25] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 4 top_k: 9, top_p: 0.31] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 4 top_k: 9, top_p: 0.31] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 4 top_k: 9, top_p: 0.31] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 4 top_k: 9, top_p: 0.31] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 5 top_k: 30, top_p: 0.11] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 5 top_k: 30, top_p: 0.11] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 5 top_k: 30, top_p: 0.11] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 5 top_k: 30, top_p: 0.11] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 6 top_k: 15, top_p: 0.1] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 6 top_k: 15, top_p: 0.1] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 6 top_k: 15, top_p: 0.1] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 6 top_k: 15, top_p: 0.1] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 7 top_k: 50, top_p: 0.74] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 7 top_k: 50, top_p: 0.74] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 7 top_k: 50, top_p: 0.74] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 7 top_k: 50, top_p: 0.74] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 8 top_k: 20, top_p: 0.74] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 8 top_k: 20, top_p: 0.74] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 8 top_k: 20, top_p: 0.74] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 8 top_k: 20, top_p: 0.74] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 9 top_k: 51, top_p: 0.73] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 9 top_k: 51, top_p: 0.73] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 9 top_k: 51, top_p: 0.73] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 9 top_k: 51, top_p: 0.73] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 10 top_k: 51, top_p: 0.46] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 10 top_k: 51, top_p: 0.46] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 10 top_k: 51, top_p: 0.46] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 10 top_k: 51, top_p: 0.46] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me start to line up against the backrest."<|endoftext|>
#
# -------------
# [Test 11 top_k: 56, top_p: 0.04] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 11 top_k: 56, top_p: 0.04] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 11 top_k: 56, top_p: 0.04] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 11 top_k: 56, top_p: 0.04] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 12 top_k: 81, top_p: 0.33] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 12 top_k: 81, top_p: 0.33] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 12 top_k: 81, top_p: 0.33] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 12 top_k: 81, top_p: 0.33] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 13 top_k: 21, top_p: 0.53] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 13 top_k: 21, top_p: 0.53] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 13 top_k: 21, top_p: 0.53] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 13 top_k: 21, top_p: 0.53] -> Prompt: What will we do here?
# Reply: m "The next thing I saw was a person sitting on the benches."<|endoftext|>
#
# -------------
# [Test 14 top_k: 93, top_p: 1.0] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just leaving."<|endoftext|>
#
# [Test 14 top_k: 93, top_p: 1.0] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong swim other."<|endoftext|>
#
# [Test 14 top_k: 93, top_p: 1.0] -> Prompt: Oh my god, Adine. What is this?
# Reply: m "They were all already in the park."<|endoftext|>
#
# [Test 14 top_k: 93, top_p: 1.0] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in his office rang, and not sure whether the call was intended for me or Bryce, I picked up."<|endoftext|>
#
# -------------
# [Test 15 top_k: 40, top_p: 0.83] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 15 top_k: 40, top_p: 0.83] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a good friend of his in that department. Maybe I do."<|endoftext|>
#
# [Test 15 top_k: 40, top_p: 0.83] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I'm a bit confused. Why don't you start from the beginning?"<|endoftext|>
#
# [Test 15 top_k: 40, top_p: 0.83] -> Prompt: What will we do here?
# Reply: m "It was a dragon!{w=1.0}\nAnd as I could now see, a dragon who not only had a pair of round glasses, but also wore a burgundy tie around its neck."<|endoftext|>
#
# -------------
# [Test 16 top_k: 54, top_p: 0.14] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 16 top_k: 54, top_p: 0.14] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 16 top_k: 54, top_p: 0.14] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 16 top_k: 54, top_p: 0.14] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 17 top_k: 86, top_p: 0.34] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 17 top_k: 86, top_p: 0.34] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 17 top_k: 86, top_p: 0.34] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 17 top_k: 86, top_p: 0.34] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 18 top_k: 63, top_p: 0.91] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 18 top_k: 63, top_p: 0.91] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a jerk if I wanted to."<|endoftext|>
#
# [Test 18 top_k: 63, top_p: 0.91] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "Here you go. Ten cups of coffee, plus one extra. That's enough for me."<|endoftext|>
#
# [Test 18 top_k: 63, top_p: 0.91] -> Prompt: What will we do here?
# Reply: Ad "It's a long-running game about the AI that is in the making. It's a shame we can't stop now, after all."<|endoftext|>
#
# -------------
# [Test 19 top_k: 83, top_p: 0.51] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 19 top_k: 83, top_p: 0.51] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 19 top_k: 83, top_p: 0.51] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 19 top_k: 83, top_p: 0.51] -> Prompt: What will we do here?
# Reply: m "The next thing I saw was a person sitting on the benches."<|endoftext|>
#
# -------------
# [Test 20 top_k: 55, top_p: 0.71] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 20 top_k: 55, top_p: 0.71] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 20 top_k: 55, top_p: 0.71] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 20 top_k: 55, top_p: 0.71] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 21 top_k: 57, top_p: 0.73] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 21 top_k: 57, top_p: 0.73] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 21 top_k: 57, top_p: 0.73] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 21 top_k: 57, top_p: 0.73] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 22 top_k: 82, top_p: 0.65] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 22 top_k: 82, top_p: 0.65] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 22 top_k: 82, top_p: 0.65] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 22 top_k: 82, top_p: 0.65] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 23 top_k: 31, top_p: 0.07] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 23 top_k: 31, top_p: 0.07] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 23 top_k: 31, top_p: 0.07] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 23 top_k: 31, top_p: 0.07] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 24 top_k: 64, top_p: 0.74] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 24 top_k: 64, top_p: 0.74] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 24 top_k: 64, top_p: 0.74] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 24 top_k: 64, top_p: 0.74] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 25 top_k: 67, top_p: 0.28] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 25 top_k: 67, top_p: 0.28] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 25 top_k: 67, top_p: 0.28] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 25 top_k: 67, top_p: 0.28] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 26 top_k: 52, top_p: 0.17] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 26 top_k: 52, top_p: 0.17] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 26 top_k: 52, top_p: 0.17] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 26 top_k: 52, top_p: 0.17] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 27 top_k: 71, top_p: 0.59] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 27 top_k: 71, top_p: 0.59] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 27 top_k: 71, top_p: 0.59] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some really bad news for you. Apparently, both of you gave up the easy life of waited for for me there last time by the police force."<|endoftext|>
#
# [Test 27 top_k: 71, top_p: 0.59] -> Prompt: What will we do here?
# Reply: Sb "We have some really bad news for you. There is no evidence that Reza or anything he did during the investigation went or left anything into our investigation."<|endoftext|>
#
# -------------
# [Test 28 top_k: 67, top_p: 0.85] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 28 top_k: 67, top_p: 0.85] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a good friend of his in that department. Maybe I do."<|endoftext|>
#
# [Test 28 top_k: 67, top_p: 0.85] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I'm a bit confused. Why don't you start from the beginning?"<|endoftext|>
#
# [Test 28 top_k: 67, top_p: 0.85] -> Prompt: What will we do here?
# Reply: m "It was a dragon!{w=1.0}\nAnd as I could now see, a dragon who not only had a pair of round glasses, but also wore a burgundy tie around its neck."<|endoftext|>
#
# -------------
# [Test 29 top_k: 12, top_p: 0.21] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 29 top_k: 12, top_p: 0.21] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 29 top_k: 12, top_p: 0.21] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 29 top_k: 12, top_p: 0.21] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 30 top_k: 56, top_p: 0.46] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 30 top_k: 56, top_p: 0.46] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 30 top_k: 56, top_p: 0.46] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 30 top_k: 56, top_p: 0.46] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me start to line up against the backrest."<|endoftext|>
#
# -------------
# [Test 31 top_k: 65, top_p: 0.35] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 31 top_k: 65, top_p: 0.35] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 31 top_k: 65, top_p: 0.35] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 31 top_k: 65, top_p: 0.35] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 32 top_k: 8, top_p: 0.05] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 32 top_k: 8, top_p: 0.05] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 32 top_k: 8, top_p: 0.05] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 32 top_k: 8, top_p: 0.05] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 33 top_k: 6, top_p: 0.54] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 33 top_k: 6, top_p: 0.54] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 33 top_k: 6, top_p: 0.54] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 33 top_k: 6, top_p: 0.54] -> Prompt: What will we do here?
# Reply: m "The next thing I saw was a person sitting on the benches."<|endoftext|>
#
# -------------
# [Test 34 top_k: 47, top_p: 0.13] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 34 top_k: 47, top_p: 0.13] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 34 top_k: 47, top_p: 0.13] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 34 top_k: 47, top_p: 0.13] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 35 top_k: 65, top_p: 0.99] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just leaving."<|endoftext|>
#
# [Test 35 top_k: 65, top_p: 0.99] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong swim other."<|endoftext|>
#
# [Test 35 top_k: 65, top_p: 0.99] -> Prompt: Oh my god, Adine. What is this?
# Reply: m "They were all already in the park."<|endoftext|>
#
# [Test 35 top_k: 65, top_p: 0.99] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in his office rang, and not sure whether the call was intended for me or Bryce, I picked up."<|endoftext|>
#
# -------------
# [Test 36 top_k: 69, top_p: 0.91] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 36 top_k: 69, top_p: 0.91] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a jerk if I wanted to."<|endoftext|>
#
# [Test 36 top_k: 69, top_p: 0.91] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "Here you go. Ten cups of coffee, plus one extra. That's enough for me."<|endoftext|>
#
# [Test 36 top_k: 69, top_p: 0.91] -> Prompt: What will we do here?
# Reply: Ad "It's a long-running game about the AI that is in the making. It's a shame we can't stop now, after all."<|endoftext|>
#
# -------------
# [Test 37 top_k: 45, top_p: 0.31] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 37 top_k: 45, top_p: 0.31] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 37 top_k: 45, top_p: 0.31] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 37 top_k: 45, top_p: 0.31] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 38 top_k: 55, top_p: 0.67] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 38 top_k: 55, top_p: 0.67] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 38 top_k: 55, top_p: 0.67] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 38 top_k: 55, top_p: 0.67] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 39 top_k: 66, top_p: 0.99] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just leaving."<|endoftext|>
#
# [Test 39 top_k: 66, top_p: 0.99] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong swim other."<|endoftext|>
#
# [Test 39 top_k: 66, top_p: 0.99] -> Prompt: Oh my god, Adine. What is this?
# Reply: m "They were all already in the park."<|endoftext|>
#
# [Test 39 top_k: 66, top_p: 0.99] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in his office rang, and not sure whether the call was intended for me or Bryce, I picked up."<|endoftext|>
#
# -------------
# [Test 40 top_k: 69, top_p: 0.31] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 40 top_k: 69, top_p: 0.31] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 40 top_k: 69, top_p: 0.31] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 40 top_k: 69, top_p: 0.31] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 41 top_k: 78, top_p: 0.69] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 41 top_k: 78, top_p: 0.69] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 41 top_k: 78, top_p: 0.69] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 41 top_k: 78, top_p: 0.69] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 42 top_k: 17, top_p: 0.96] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 42 top_k: 17, top_p: 0.96] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a jerk if I wanted to."<|endoftext|>
#
# [Test 42 top_k: 17, top_p: 0.96] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "Here you go. Ten cups of coffee, plus one extra. That's enough for me."<|endoftext|>
#
# [Test 42 top_k: 17, top_p: 0.96] -> Prompt: What will we do here?
# Reply: Ad "It's a long-running game about the AI that is in the making. It's a shame we can't stop now, after all."<|endoftext|>
#
# -------------
# [Test 43 top_k: 52, top_p: 0.33] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 43 top_k: 52, top_p: 0.33] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 43 top_k: 52, top_p: 0.33] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 43 top_k: 52, top_p: 0.33] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 44 top_k: 33, top_p: 0.87] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 44 top_k: 33, top_p: 0.87] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a good friend of his in that department. Maybe I do."<|endoftext|>
#
# [Test 44 top_k: 33, top_p: 0.87] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I'm a bit confused. Why don't you start from the beginning?"<|endoftext|>
#
# [Test 44 top_k: 33, top_p: 0.87] -> Prompt: What will we do here?
# Reply: m "It was a dragon!{w=1.0}\nAnd as I could now see, a dragon who not only had a pair of round glasses, but also wore a burgundy tie around its neck."<|endoftext|>
#
# -------------
# [Test 45 top_k: 74, top_p: 0.5] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 45 top_k: 74, top_p: 0.5] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 45 top_k: 74, top_p: 0.5] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 45 top_k: 74, top_p: 0.5] -> Prompt: What will we do here?
# Reply: m "The next thing I saw was a person sitting on the benches."<|endoftext|>
#
# -------------
# [Test 46 top_k: 15, top_p: 0.31] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 46 top_k: 15, top_p: 0.31] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 46 top_k: 15, top_p: 0.31] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 46 top_k: 15, top_p: 0.31] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 47 top_k: 21, top_p: 0.19] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 47 top_k: 21, top_p: 0.19] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 47 top_k: 21, top_p: 0.19] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 47 top_k: 21, top_p: 0.19] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 48 top_k: 62, top_p: 0.15] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 48 top_k: 62, top_p: 0.15] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 48 top_k: 62, top_p: 0.15] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 48 top_k: 62, top_p: 0.15] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 49 top_k: 42, top_p: 0.5] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 49 top_k: 42, top_p: 0.5] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 49 top_k: 42, top_p: 0.5] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 49 top_k: 42, top_p: 0.5] -> Prompt: What will we do here?
# Reply: m "The next thing I saw was a person sitting on the benches."<|endoftext|>
#
# -------------
# [Test 50 top_k: 94, top_p: 0.18] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 50 top_k: 94, top_p: 0.18] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 50 top_k: 94, top_p: 0.18] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 50 top_k: 94, top_p: 0.18] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 51 top_k: 74, top_p: 0.11] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 51 top_k: 74, top_p: 0.11] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 51 top_k: 74, top_p: 0.11] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 51 top_k: 74, top_p: 0.11] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 52 top_k: 6, top_p: 0.4] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 52 top_k: 6, top_p: 0.4] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 52 top_k: 6, top_p: 0.4] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 52 top_k: 6, top_p: 0.4] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 53 top_k: 73, top_p: 0.02] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 53 top_k: 73, top_p: 0.02] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 53 top_k: 73, top_p: 0.02] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 53 top_k: 73, top_p: 0.02] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 54 top_k: 85, top_p: 0.17] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 54 top_k: 85, top_p: 0.17] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 54 top_k: 85, top_p: 0.17] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 54 top_k: 85, top_p: 0.17] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 55 top_k: 82, top_p: 0.26] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 55 top_k: 82, top_p: 0.26] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 55 top_k: 82, top_p: 0.26] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 55 top_k: 82, top_p: 0.26] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 56 top_k: 27, top_p: 0.4] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 56 top_k: 27, top_p: 0.4] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 56 top_k: 27, top_p: 0.4] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 56 top_k: 27, top_p: 0.4] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 57 top_k: 96, top_p: 0.02] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 57 top_k: 96, top_p: 0.02] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 57 top_k: 96, top_p: 0.02] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 57 top_k: 96, top_p: 0.02] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 58 top_k: 49, top_p: 0.26] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 58 top_k: 49, top_p: 0.26] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 58 top_k: 49, top_p: 0.26] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 58 top_k: 49, top_p: 0.26] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 59 top_k: 58, top_p: 0.78] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 59 top_k: 58, top_p: 0.78] -> Prompt: What do you think of Lorem?
# Reply: Ad "That's awesome. He's a cute crawled single. This certainly doesn't look like a punishment."<|endoftext|>
#
# [Test 59 top_k: 58, top_p: 0.78] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "What are you doing here?"<|endoftext|>
#
# [Test 59 top_k: 58, top_p: 0.78] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in his office rang, and not sure whether the call was intended for me or Bryce, I picked up."<|endoftext|>
#
# -------------
# [Test 60 top_k: 51, top_p: 0.27] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 60 top_k: 51, top_p: 0.27] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 60 top_k: 51, top_p: 0.27] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 60 top_k: 51, top_p: 0.27] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 61 top_k: 61, top_p: 0.65] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 61 top_k: 61, top_p: 0.65] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 61 top_k: 61, top_p: 0.65] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 61 top_k: 61, top_p: 0.65] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 62 top_k: 15, top_p: 0.33] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 62 top_k: 15, top_p: 0.33] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 62 top_k: 15, top_p: 0.33] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 62 top_k: 15, top_p: 0.33] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 63 top_k: 95, top_p: 0.04] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 63 top_k: 95, top_p: 0.04] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 63 top_k: 95, top_p: 0.04] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 63 top_k: 95, top_p: 0.04] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 64 top_k: 42, top_p: 0.91] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 64 top_k: 42, top_p: 0.91] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a jerk if I wanted to."<|endoftext|>
#
# [Test 64 top_k: 42, top_p: 0.91] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "Here you go. Ten cups of coffee, plus one extra. That's enough for me."<|endoftext|>
#
# [Test 64 top_k: 42, top_p: 0.91] -> Prompt: What will we do here?
# Reply: Ad "It's a long-running game about the AI that is in the making. It's a shame we can't stop now, after all."<|endoftext|>
#
# -------------
# [Test 65 top_k: 20, top_p: 0.7] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 65 top_k: 20, top_p: 0.7] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 65 top_k: 20, top_p: 0.7] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 65 top_k: 20, top_p: 0.7] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 66 top_k: 1, top_p: 0.79] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 66 top_k: 1, top_p: 0.79] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 66 top_k: 1, top_p: 0.79] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 66 top_k: 1, top_p: 0.79] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 67 top_k: 76, top_p: 0.49] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 67 top_k: 76, top_p: 0.49] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 67 top_k: 76, top_p: 0.49] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 67 top_k: 76, top_p: 0.49] -> Prompt: What will we do here?
# Reply: m "The next thing I saw was a person sitting on the benches."<|endoftext|>
#
# -------------
# [Test 68 top_k: 42, top_p: 0.19] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 68 top_k: 42, top_p: 0.19] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 68 top_k: 42, top_p: 0.19] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 68 top_k: 42, top_p: 0.19] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 69 top_k: 40, top_p: 0.16] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 69 top_k: 40, top_p: 0.16] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 69 top_k: 40, top_p: 0.16] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 69 top_k: 40, top_p: 0.16] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 70 top_k: 97, top_p: 0.16] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 70 top_k: 97, top_p: 0.16] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 70 top_k: 97, top_p: 0.16] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 70 top_k: 97, top_p: 0.16] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 71 top_k: 6, top_p: 0.73] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 71 top_k: 6, top_p: 0.73] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 71 top_k: 6, top_p: 0.73] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 71 top_k: 6, top_p: 0.73] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 72 top_k: 29, top_p: 0.68] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 72 top_k: 29, top_p: 0.68] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 72 top_k: 29, top_p: 0.68] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 72 top_k: 29, top_p: 0.68] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 73 top_k: 4, top_p: 0.97] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. I guess I was. I thought the whole contest was just a waste of time."<|endoftext|>
#
# [Test 73 top_k: 4, top_p: 0.97] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a jerk if I was his friend."<|endoftext|>
#
# [Test 73 top_k: 4, top_p: 0.97] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "What are you talking about?"<|endoftext|>
#
# [Test 73 top_k: 4, top_p: 0.97] -> Prompt: What will we do here?
# Reply: Ry "We have to do our best to uphold a high standard in fostering this diplomatic relationship."<|endoftext|>
#
# -------------
# [Test 74 top_k: 70, top_p: 0.73] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 74 top_k: 70, top_p: 0.73] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 74 top_k: 70, top_p: 0.73] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 74 top_k: 70, top_p: 0.73] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 75 top_k: 35, top_p: 0.09] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 75 top_k: 35, top_p: 0.09] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 75 top_k: 35, top_p: 0.09] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 75 top_k: 35, top_p: 0.09] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 76 top_k: 93, top_p: 0.62] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 76 top_k: 93, top_p: 0.62] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 76 top_k: 93, top_p: 0.62] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some really bad news for you. Apparently, both of you gave up the easy life of waited for for me there last time by the police force."<|endoftext|>
#
# [Test 76 top_k: 93, top_p: 0.62] -> Prompt: What will we do here?
# Reply: Sb "We have some really bad news for you. There is no evidence that Reza or anything he did during the investigation went or left anything into our investigation."<|endoftext|>
#
# -------------
# [Test 77 top_k: 54, top_p: 0.32] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 77 top_k: 54, top_p: 0.32] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 77 top_k: 54, top_p: 0.32] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 77 top_k: 54, top_p: 0.32] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 78 top_k: 82, top_p: 0.77] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 78 top_k: 82, top_p: 0.77] -> Prompt: What do you think of Lorem?
# Reply: Ad "That's awesome. He's a cute crawled single. This certainly doesn't look like a punishment."<|endoftext|>
#
# [Test 78 top_k: 82, top_p: 0.77] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "What are you doing here?"<|endoftext|>
#
# [Test 78 top_k: 82, top_p: 0.77] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in his office rang, and not sure whether the call was intended for me or Bryce, I picked up."<|endoftext|>
#
# -------------
# [Test 79 top_k: 39, top_p: 0.67] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 79 top_k: 39, top_p: 0.67] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 79 top_k: 39, top_p: 0.67] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 79 top_k: 39, top_p: 0.67] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 80 top_k: 44, top_p: 0.14] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 80 top_k: 44, top_p: 0.14] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 80 top_k: 44, top_p: 0.14] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 80 top_k: 44, top_p: 0.14] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 81 top_k: 37, top_p: 0.38] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 81 top_k: 37, top_p: 0.38] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 81 top_k: 37, top_p: 0.38] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 81 top_k: 37, top_p: 0.38] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 82 top_k: 31, top_p: 0.88] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 82 top_k: 31, top_p: 0.88] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a good friend of his in that department. Maybe I do."<|endoftext|>
#
# [Test 82 top_k: 31, top_p: 0.88] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I'm a bit confused. Why don't you start from the beginning?"<|endoftext|>
#
# [Test 82 top_k: 31, top_p: 0.88] -> Prompt: What will we do here?
# Reply: m "It was a dragon!{w=1.0}\nAnd as I could now see, a dragon who not only had a pair of round glasses, but also wore a burgundy tie around its neck."<|endoftext|>
#
# -------------
# [Test 83 top_k: 39, top_p: 0.14] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 83 top_k: 39, top_p: 0.14] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 83 top_k: 39, top_p: 0.14] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 83 top_k: 39, top_p: 0.14] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 84 top_k: 35, top_p: 0.16] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 84 top_k: 35, top_p: 0.16] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 84 top_k: 35, top_p: 0.16] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 84 top_k: 35, top_p: 0.16] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 85 top_k: 19, top_p: 0.42] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 85 top_k: 19, top_p: 0.42] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 85 top_k: 19, top_p: 0.42] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 85 top_k: 19, top_p: 0.42] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 86 top_k: 53, top_p: 0.35] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 86 top_k: 53, top_p: 0.35] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 86 top_k: 53, top_p: 0.35] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 86 top_k: 53, top_p: 0.35] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 87 top_k: 13, top_p: 0.33] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 87 top_k: 13, top_p: 0.33] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 87 top_k: 13, top_p: 0.33] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 87 top_k: 13, top_p: 0.33] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 88 top_k: 26, top_p: 0.69] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 88 top_k: 26, top_p: 0.69] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge fan of mine, so I'm sure he'll find his first apartment on this family of ours."<|endoftext|>
#
# [Test 88 top_k: 26, top_p: 0.69] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 88 top_k: 26, top_p: 0.69] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me fell into the sea."<|endoftext|>
#
# -------------
# [Test 89 top_k: 77, top_p: 0.42] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 89 top_k: 77, top_p: 0.42] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 89 top_k: 77, top_p: 0.42] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 89 top_k: 77, top_p: 0.42] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 90 top_k: 49, top_p: 0.12] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 90 top_k: 49, top_p: 0.12] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 90 top_k: 49, top_p: 0.12] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 90 top_k: 49, top_p: 0.12] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 91 top_k: 78, top_p: 0.07] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 91 top_k: 78, top_p: 0.07] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 91 top_k: 78, top_p: 0.07] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 91 top_k: 78, top_p: 0.07] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 92 top_k: 45, top_p: 0.05] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 92 top_k: 45, top_p: 0.05] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 92 top_k: 45, top_p: 0.05] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 92 top_k: 45, top_p: 0.05] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 93 top_k: 34, top_p: 0.56] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 93 top_k: 34, top_p: 0.56] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 93 top_k: 34, top_p: 0.56] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some really bad news for you. Apparently, she has moreONS."<|endoftext|>
#
# [Test 93 top_k: 34, top_p: 0.56] -> Prompt: What will we do here?
# Reply: Ry "We have to do our best to uphold a high standard in fostering this diplomatic relationship."<|endoftext|>
#
# -------------
# [Test 94 top_k: 82, top_p: 0.76] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 94 top_k: 82, top_p: 0.76] -> Prompt: What do you think of Lorem?
# Reply: Ad "That's awesome. He's a cute crawled single. This certainly doesn't look like a punishment."<|endoftext|>
#
# [Test 94 top_k: 82, top_p: 0.76] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "What are you doing here?"<|endoftext|>
#
# [Test 94 top_k: 82, top_p: 0.76] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in his office rang, and not sure whether the call was intended for me or Bryce, I picked up."<|endoftext|>
#
# -------------
# [Test 95 top_k: 84, top_p: 0.75] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 95 top_k: 84, top_p: 0.75] -> Prompt: What do you think of Lorem?
# Reply: Ad "That's awesome. He's a cute crawled single. This certainly doesn't look like a punishment."<|endoftext|>
#
# [Test 95 top_k: 84, top_p: 0.75] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "What are you doing here?"<|endoftext|>
#
# [Test 95 top_k: 84, top_p: 0.75] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in his office rang, and not sure whether the call was intended for me or Bryce, I picked up."<|endoftext|>
#
# -------------
# [Test 96 top_k: 92, top_p: 0.99] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just leaving."<|endoftext|>
#
# [Test 96 top_k: 92, top_p: 0.99] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong swim other."<|endoftext|>
#
# [Test 96 top_k: 92, top_p: 0.99] -> Prompt: Oh my god, Adine. What is this?
# Reply: m "They were all already in the park."<|endoftext|>
#
# [Test 96 top_k: 92, top_p: 0.99] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in his office rang, and not sure whether the call was intended for me or Bryce, I picked up."<|endoftext|>
#
# -------------
# [Test 97 top_k: 83, top_p: 0.57] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 97 top_k: 83, top_p: 0.57] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, beautiful dragon. I didn't know you had such a thing."<|endoftext|>
#
# [Test 97 top_k: 83, top_p: 0.57] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some really bad news for you. Apparently, she has moreONS."<|endoftext|>
#
# [Test 97 top_k: 83, top_p: 0.57] -> Prompt: What will we do here?
# Reply: Ry "We have to do our best to uphold a high standard in fostering this diplomatic relationship."<|endoftext|>
#
# -------------
# [Test 98 top_k: 99, top_p: 0.29] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 98 top_k: 99, top_p: 0.29] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 98 top_k: 99, top_p: 0.29] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 98 top_k: 99, top_p: 0.29] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 99 top_k: 48, top_p: 0.34] -> Prompt: How are you?
# Reply: Ry "Hey!"<|endoftext|>
#
# [Test 99 top_k: 48, top_p: 0.34] -> Prompt: What do you think of Lorem?
# Reply: Ad "He's such a huge, strong dragon. He'd never be able to walk away from me until he got close enough to hit me."<|endoftext|>
#
# [Test 99 top_k: 48, top_p: 0.34] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "I have some very bad news for you."<|endoftext|>
#
# [Test 99 top_k: 48, top_p: 0.34] -> Prompt: What will we do here?
# Reply: m "After a few hours, the telephone in front of me picked up, only to give up after a few seconds later."<|endoftext|>
#
# -------------
# [Test 100 top_k: 58, top_p: 0.91] -> Prompt: How are you?
# Reply: Ry "I'm pretty well. We're just as ready as I am."<|endoftext|>
#
# [Test 100 top_k: 58, top_p: 0.91] -> Prompt: What do you think of Lorem?
# Reply: Ad "I'm not sure if I could be a jerk if I wanted to."<|endoftext|>
#
# [Test 100 top_k: 58, top_p: 0.91] -> Prompt: Oh my god, Adine. What is this?
# Reply: Ad "Here you go. Ten cups of coffee, plus one extra. That's enough for me."<|endoftext|>
#
# [Test 100 top_k: 58, top_p: 0.91] -> Prompt: What will we do here?
# Reply: Ad "It's a long-running game about the AI that is in the making. It's a shame we can't stop now, after all."<|endoftext|>
#
# -------------

# %%
def generate_reply(prompt):
  model.eval()
  prompt = f'PlayerReply c "{prompt}" DragonReply'
  generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
  generated = generated.to(device)
  print(prompt, generated)

  sample_outputs = model.generate(
    generated, 
    do_sample=True,   
    eos_token_id=tokenizer.eos_token_id,
    top_k=50, 
    max_length = 128,
    top_p=0.95, 
    num_return_sequences=3
  )

  for i, sample_output in enumerate(sample_outputs):
    print("{}: {}\n\n".format(i, tokenizer.decode(sample_output, skip_special_tokens=False)))

print("What to say?")
print(generate_reply(input()))
# Out:
# What to say?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_189/2875525182.py in <module>
#      20
#      21 print("What to say?")
# ---> 22 print(generate_reply(input()))
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
